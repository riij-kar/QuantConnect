# %% [markdown]
# ![QuantConnect Logo](https://cdn.quantconnect.com/web/i/icon.png)
# <hr>

# %%
# QuantBook Analysis Tool 
# For more information see [https://www.quantconnect.com/docs/v2/our-platform/research/getting-started]
# %matplotlib widget
qb = QuantBook()
spy = qb.add_equity("SPY")
# Locally Lean installs free sample data, to download more data please visit https://www.quantconnect.com/docs/v2/lean-cli/datasets/downloading-data 
qb.set_start_date(2013, 10, 11)
history = qb.history(qb.securities.keys(), 360, Resolution.DAILY)

# Indicator Analysis
bbdf = qb.indicator(BollingerBands(30, 2), spy.symbol, 360, Resolution.DAILY)
bbdf.drop('standarddeviation', axis=1).plot()
# Out:
# 20250921 10:18:09.871 TRACE:: Config.GetValue(): qb-data-hour - Using default value: 9
# 20250921 10:18:09.910 TRACE:: Config.Get(): Configuration key not found. Key: lean-manager-type - Using default value: LocalLeanManager
# 20250921 10:18:09.917 TRACE:: Config.Get(): Configuration key not found. Key: data-permission-manager - Using default value: DataPermissionManager
# 20250921 10:18:09.918 TRACE:: Config.Get(): Configuration key not found. Key: data-monitor - Using default value: QuantConnect.Data.DataMonitor
# 20250921 10:18:09.987 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250921 10:18:09.988 TRACE:: Config.Get(): Configuration key not found. Key: fundamental-data-provider - Using default value: CoarseFundamentalDataProvider
# 20250921 10:18:09.991 TRACE:: Config.GetValue(): algorithm-manager-time-loop-maximum - Using default value: 20
# 20250921 10:18:09.992 TRACE:: Config.GetValue(): storage-limit - Using default value: 10737418240
# 20250921 10:18:09.994 TRACE:: Config.GetValue(): storage-permissions - Using default value: Read=True Write=True Delete=True
# 20250921 10:18:09.996 TRACE:: LocalObjectStore.Initialize(): Storage Root: /Storage. StorageFileCount 9999999. StorageLimit 10240MB. StoragePermissions Read=True Write=True Delete=True
# 20250921 10:18:09.997 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250921 10:18:10.001 TRACE:: HistoryProviderManager.Initialize(): history providers [SubscriptionDataReaderHistoryProvider]
# 20250921 10:18:10.003 TRACE:: Config.GetValue(): deployment-target - Using default value: LocalPlatform
# 20250921 10:18:10.008 TRACE:: Config.GetValue(): qb-data-hour - Using default value: 9
# 20250921 10:18:10.017 TRACE:: Config.Get(): Configuration key not found. Key: lean-manager-type - Using default value: LocalLeanManager
# 20250921 10:18:10.018 TRACE:: Config.Get(): Configuration key not found. Key: data-permission-manager - Using default value: DataPermissionManager
# 20250921 10:18:10.018 TRACE:: Config.Get(): Configuration key not found. Key: data-monitor - Using default value: QuantConnect.Data.DataMonitor
# 20250921 10:18:10.021 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250921 10:18:10.021 TRACE:: Config.Get(): Configuration key not found. Key: fundamental-data-provider - Using default value: CoarseFundamentalDataProvider
# 20250921 10:18:10.022 TRACE:: Config.GetValue(): algorithm-manager-time-loop-maximum - Using default value: 20
# 20250921 10:18:10.022 TRACE:: Config.GetValue(): storage-limit - Using default value: 10737418240
# 20250921 10:18:10.023 TRACE:: Config.GetValue(): storage-permissions - Using default value: Read=True Write=True Delete=True
# 20250921 10:18:10.024 TRACE:: LocalObjectStore.Initialize(): Storage Root: /Storage. StorageFileCount 9999999. StorageLimit 10240MB. StoragePermissions Read=True Write=True Delete=True
# 20250921 10:18:10.024 TRACE:: Config.GetValue(): zip-data-cache-provider - Using default value: 10
# 20250921 10:18:10.025 TRACE:: HistoryProviderManager.Initialize(): history providers [SubscriptionDataReaderHistoryProvider]
# 20250921 10:18:10.026 TRACE:: Config.GetValue(): deployment-target - Using default value: LocalPlatform
# <Axes: >
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
